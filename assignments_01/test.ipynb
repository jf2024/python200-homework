# %%
import pandas as pd
import os

# %%
a = pd.read_csv("../data/happiness_project/world_happiness_2017.csv", sep=';', decimal=',')

a
# Out:
#      Ranking                   Country                  Regional indicator  \
# 0          3                   Iceland                      Western Europe
# 1         15                   Ireland                      Western Europe
# 2          2                   Denmark                      Western Europe
# 3         47                Uzbekistan  Commonwealth of Independent States
# 4          8               New Zealand               North America and ANZ
# ..       ...                       ...                                 ...
# 150      136                    Malawi                  Sub-Saharan Africa
# 151      143                     Benin                  Sub-Saharan Africa
# 152      150                      Togo                  Sub-Saharan Africa
# 153      152                     Syria        Middle East and North Africa
# 154      155  Central African Republic                  Sub-Saharan Africa
#
# ...

# %%
s = '../data/happiness_project/world_happiness_2015.csv'
s.split("_")[-1].split(".")[0]
# Out:
# '2015'

# %%
directory = '../data/happiness_project/'
all_data = []

for file in os.listdir(directory):
    year = file.split("_")[-1].split(".")[0]

    if file.endswith(".csv"):
        full_path = directory + file
        df = pd.read_csv(full_path, sep=';', decimal=',')
        df['year'] = year
        if year == 2024:
            df = df.rename(columns={'Ladder score': 'Happiness score'})
        all_data.append(df)

pd.concat(all_data)
# Out:
#      Ranking                   Country                  Regional indicator  \
# 0          3                   Iceland                      Western Europe
# 1         15                   Ireland                      Western Europe
# 2          2                   Denmark                      Western Europe
# 3         47                Uzbekistan  Commonwealth of Independent States
# 4          8               New Zealand               North America and ANZ
# ..       ...                       ...                                 ...
# 147      149  Central African Republic                  Sub-Saharan Africa
# 148      150                    Rwanda                  Sub-Saharan Africa
# 149      151                  Zimbabwe                  Sub-Saharan Africa
# 150      152               South Sudan                  Sub-Saharan Africa
# 151      153               Afghanistan                          South Asia
#
# ...
